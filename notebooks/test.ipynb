# %%
import os
import json
from datetime import datetime
import logging
import argparse
import pandas as pd


BASE_DIR = "/Users/kelstonchen/GitRepos/predicting_race_winners"

# %%
PATH = os.path.join(BASE_DIR, 'data', 'raw', 'results', '2022')

# %%
with open(os.path.join(PATH, os.listdir(PATH)[0]), 'r') as reader:
    d = json.load(reader)

# %%
df = pd.DataFrame(d['RaceTable']['Races'])
df
# Out:
#   season round                                                url  \
# 0   2022     5  https://en.wikipedia.org/wiki/2022_Miami_Grand...
# 1   2022     6  https://en.wikipedia.org/wiki/2022_Spanish_Gra...
#
#              raceName                                            Circuit  \
# 0    Miami Grand Prix  {'circuitId': 'miami', 'url': 'https://en.wiki...
# 1  Spanish Grand Prix  {'circuitId': 'catalunya', 'url': 'https://en....
#
#          date       time                                            Results
# 0  2022-05-08  19:30:00Z  [{'number': '14', 'position': '11', 'positionT...
# 1  2022-05-22  13:00:00Z  [{'number': '1', 'position': '1', 'positionTex...

# %%
d['RaceTable']['Races'][0]['round']
# Out:
# '5'

# %%
# pd.DataFrame(d['RaceTable']['Races'][1]['Results']['FastestLap'])

# %%
pd.concat([df, pd.DataFrame(df['Results'].to_dict()[0])])
# Out:
#   season round                                                url  \
# 0   2022     5  https://en.wikipedia.org/wiki/2022_Miami_Grand...
# 1   2022     6  https://en.wikipedia.org/wiki/2022_Spanish_Gra...
# 0    NaN   NaN                                                NaN
# 1    NaN   NaN                                                NaN
# 2    NaN   NaN                                                NaN
# 3    NaN   NaN                                                NaN
# 4    NaN   NaN                                                NaN
# 5    NaN   NaN                                                NaN
# 6    NaN   NaN                                                NaN
# 7    NaN   NaN                                                NaN
# 8    NaN   NaN                                                NaN
# 9    NaN   NaN                                                NaN
#
#              raceName                                            Circuit  \
# ...

# %%
len(d['RaceTable']['Races'])
# Out:
# 2

# %%
df
# Out:
#   season round                                                url  \
# 0   2022     5  https://en.wikipedia.org/wiki/2022_Miami_Grand...
# 1   2022     6  https://en.wikipedia.org/wiki/2022_Spanish_Gra...
#
#              raceName                                            Circuit  \
# 0    Miami Grand Prix  {'circuitId': 'miami', 'url': 'https://en.wiki...
# 1  Spanish Grand Prix  {'circuitId': 'catalunya', 'url': 'https://en....
#
#          date       time                                            Results
# 0  2022-05-08  19:30:00Z  [{'number': '14', 'position': '11', 'positionT...
# 1  2022-05-22  13:00:00Z  [{'number': '1', 'position': '1', 'positionTex...

# %%
pd.DataFrame(d['RaceTable']['Races'][0]['Results'])
# Out:
#   number position positionText points  \
# 0     14       11           11      0
# 1     22       12           12      0
# 2      3       13           13      0
# 3      6       14           14      0
# 4     47       15           15      0
# 5     20       16           16      0
# 6      5       17           17      0
# 7     10       18            R      0
# 8      4       19            R      0
# 9     24       20            R      0
#
#                                               Driver  \
# 0  {'driverId': 'alonso', 'permanentNumber': '14'...
# 1  {'driverId': 'tsunoda', 'permanentNumber': '22...
# 2  {'driverId': 'ricciardo', 'permanentNumber': '...
# 3  {'driverId': 'latifi', 'permanentNumber': '6',...
# 4  {'driverId': 'mick_schumacher', 'permanentNumb...
# 5  {'driverId': 'kevin_magnussen', 'permanentNumb...
# 6  {'driverId': 'vettel', 'permanentNumber': '5',...
# 7  {'driverId': 'gasly', 'permanentNumber': '10',...
# 8  {'driverId': 'norris', 'permanentNumber': '4',...
# ...

# %%
from build_jolpica import build_data
df = build_data(endpoint='qualifying', key='QualifyingResults')

# %%
df.head(25)
# Out:
#    number position                                             Driver  \
# 0      16        1  {'driverId': 'leclerc', 'permanentNumber': '16...
# 1       1        2  {'driverId': 'max_verstappen', 'permanentNumbe...
# 2      55        3  {'driverId': 'sainz', 'permanentNumber': '55',...
# 3      11        4  {'driverId': 'perez', 'permanentNumber': '11',...
# 4      44        5  {'driverId': 'hamilton', 'permanentNumber': '4...
# 5      77        6  {'driverId': 'bottas', 'permanentNumber': '77'...
# 6      20        7  {'driverId': 'kevin_magnussen', 'permanentNumb...
# 7      14        8  {'driverId': 'alonso', 'permanentNumber': '14'...
# 8      63        9  {'driverId': 'russell', 'permanentNumber': '63...
# 9      10       10  {'driverId': 'gasly', 'permanentNumber': '10',...
# 10     31       11  {'driverId': 'ocon', 'permanentNumber': '31', ...
# 11     47       12  {'driverId': 'mick_schumacher', 'permanentNumb...
# ...

# %%
df.sort_values(by=['season', 'round'])
# Out:
#    number position                                             Driver  \
# 0      16        1  {'driverId': 'leclerc', 'permanentNumber': '16...
# 1       1        2  {'driverId': 'max_verstappen', 'permanentNumbe...
# 2      55        3  {'driverId': 'sainz', 'permanentNumber': '55',...
# 3      11        4  {'driverId': 'perez', 'permanentNumber': '11',...
# 4      44        5  {'driverId': 'hamilton', 'permanentNumber': '4...
# ..    ...      ...                                                ...
# 15     27       16  {'driverId': 'hulkenberg', 'permanentNumber': ...
# 16     30       17  {'driverId': 'lawson', 'permanentNumber': '30'...
# 17      5       18  {'driverId': 'bortoleto', 'permanentNumber': '...
# 18     18       19  {'driverId': 'stroll', 'permanentNumber': '18'...
# 19     87       20  {'driverId': 'bearman', 'permanentNumber': '38...
#
#                                           Constructor        Q1        Q2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1049 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   number       1049 non-null   object
#  1   position     1049 non-null   object
#  2   Driver       1049 non-null   object
#  3   Constructor  1049 non-null   object
#  4   Q1           1049 non-null   object
#  5   Q2           793 non-null    object
#  6   Q3           530 non-null    object
#  7   season       1049 non-null   object
#  8   round        1049 non-null   object
# dtypes: object(9)
# memory usage: 82.0+ KB
