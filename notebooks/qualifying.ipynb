# %%
import os
import logging
import pandas as pd


BASE_DIR = "/Users/kelstonchen/GitRepos/predicting_race_winners"

# %%
qual = pd.read_csv(os.path.join(BASE_DIR, 'data', 'intermediate', 'qualifying', 'qualifying.csv'))

# %%
qual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1439 entries, 0 to 1438
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   number                     1439 non-null   int64
#  1   position                   1439 non-null   int64
#  2   Q1                         1425 non-null   object
#  3   Q2                         1069 non-null   object
#  4   Driver.driverId            1439 non-null   object
#  5   Driver.permanentNumber     1439 non-null   int64
#  6   Driver.code                1439 non-null   object
#  7   Driver.url                 1439 non-null   object
#  8   Driver.givenName           1439 non-null   object
#  9   Driver.familyName          1439 non-null   object
#  10  Driver.dateOfBirth         1439 non-null   object
#  11  Driver.nationality         1439 non-null   object
#  12  Constructor.constructorId  1439 non-null   object
# ...

# %%
qual
# Out:
#       number  position        Q1        Q2 Driver.driverId  \
# 0         16         1  1:31.471  1:30.932         leclerc
# 1          1         2  1:31.785  1:30.757  max_verstappen
# 2         55         3  1:31.567  1:30.787           sainz
# 3         11         4  1:32.311  1:31.008           perez
# 4         44         5  1:32.285  1:31.048        hamilton
# ...      ...       ...       ...       ...             ...
# 1434      27        16  1:32.067       NaN      hulkenberg
# 1435      30        17  1:32.165       NaN          lawson
# 1436       5        18  1:32.186       NaN       bortoleto
# 1437      18        19  1:32.283       NaN          stroll
# 1438      87        20  1:32.373       NaN         bearman
#
#       Driver.permanentNumber Driver.code  \
# 0                         16         LEC
# 1                         33         VER
# 2                         55         SAI
# 3                         11         PER
# 4                         44         HAM
# ...
